# %%
#Project Structure

'''
project/

├── app.py
├── data/
│   └── v2_risk_engineered_dataset.csv
│
├── models/
│   ├── v1_forecasting_model.pkl
│   └── v2_risk_classifier.pkl
│
├── assets/
│
└── requirements.txt

'''
# Out:
# '\nproject/\n\n├── app.py\n├── data/\n│   └── v2_risk_engineered_dataset.csv\n│\n├── models/\n│   ├── v1_forecasting_model.pkl\n│   └── v2_risk_classifier.pkl\n│\n├── assets/\n│\n└── requirements.txt\n\n'

# %%
import sys
print('Using Python executable:', sys.executable)
# Install packages into the environment backing this notebook kernel
# !{sys.executable} -m pip install --upgrade pip setuptools wheel
# !{sys.executable} -m pip install streamlit pandas numpy scikit-learn joblib networkx nbconvert ipykernel
print('Package installation finished. If kernel still shows old packages, restart the kernel.')
# Out:
# Using Python executable: /Users/atifansari/Documents/GitHub/Semiconductor-Supply-Chain-Risk-Prediction-System/.venv/bin/python
# /Users/atifansari/Documents/GitHub/Semiconductor-Supply-Chain-Risk-Prediction-System/.venv/bin/python: No module named pip
# /Users/atifansari/Documents/GitHub/Semiconductor-Supply-Chain-Risk-Prediction-System/.venv/bin/python: No module named pip
# /Users/atifansari/Documents/GitHub/Semiconductor-Supply-Chain-Risk-Prediction-System/.venv/bin/python: No module named pip
# /Users/atifansari/Documents/GitHub/Semiconductor-Supply-Chain-Risk-Prediction-System/.venv/bin/python: No module named pip
# Package installation finished. If kernel still shows old packages, restart the kernel.
# Package installation finished. If kernel still shows old packages, restart the kernel.

# %%
streamlit --version
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 streamlit --version
#
# NameError: name 'streamlit' is not defined

# %%
# Quick runtime check for required packages
import importlib, sys
packages = ['streamlit','pandas','numpy','sklearn','joblib','networkx','nbconvert','ipykernel']
for p in packages:
    try:
        importlib.import_module(p)
        print(p, 'OK')
    except Exception as e:
        print(p, 'MISSING:', e)
# Out:
# streamlit MISSING: No module named 'streamlit'
# pandas OK
# numpy OK
# pandas OK
# numpy OK
# sklearn OK
# joblib OK
# networkx OK
# nbconvert MISSING: No module named 'nbconvert'
# ipykernel OK
# sklearn OK
# joblib OK
# networkx OK
# nbconvert MISSING: No module named 'nbconvert'
# ipykernel OK

# %%
# Register this environment as a Jupyter kernel (run once)
import sys
# !{sys.executable} -m ipykernel install --user --name=project-venv --display-name "Python (project-venv)"
print('Installed kernel: Python (project-venv) — select it via Kernel -> Change Kernel in the notebook UI')

# %%
streamlit --version
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 streamlit --version
#
# NameError: name 'streamlit' is not defined

# %%
pip install streamlit
# Out:
# /Users/atifansari/Documents/GitHub/Semiconductor-Supply-Chain-Risk-Prediction-System/.venv/bin/python: No module named pip
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
